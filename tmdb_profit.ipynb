# %% [markdown]
# <a href="https://colab.research.google.com/github/Marteldelfer/PISI3/blob/analise-exploratoria/tmdb_profit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
tmdb_df = pd.read_csv('tmdb_completo.csv')
tmdb_df.head()
# Out:
#    id           title  vote_average  vote_count release_date      revenue  \
# 0   5      Four Rooms         5.861      2687.0   1995-12-09    4257354.0
# 1   6  Judgment Night         6.500       349.0   1993-10-15   12136938.0
# 2  11       Star Wars         8.204     21103.0   1977-05-25  775398007.0
# 3  12    Finding Nemo         7.815     19616.0   2003-05-30  940335536.0
# 4  13    Forrest Gump         8.468     28113.0   1994-06-23  677387716.0
#
#    runtime      budget original_language  popularity  ...  \
# 0     98.0   4000000.0                en      9.6284  ...
# 1    109.0  21000000.0                en      4.5607  ...
# 2    121.0  11000000.0                en     67.2931  ...
# 3    100.0  94000000.0                en     18.2106  ...
# 4    142.0  55000000.0                en     27.4853  ...
#
#                                 production_companies  \
# 0                              Miramax, A Band Apart
# 1       Largo Entertainment, JVC, Universal Pictures
# ...

# %%
tmdb_df = tmdb_df[tmdb_df['budget'] != 0]
tmdb_df
# Out:
#             id                    title  vote_average  vote_count  \
# 0            5               Four Rooms         5.861      2687.0
# 1            6           Judgment Night         6.500       349.0
# 2           11                Star Wars         8.204     21103.0
# 3           12             Finding Nemo         7.815     19616.0
# 4           13             Forrest Gump         8.468     28113.0
# ...        ...                      ...           ...         ...
# 19989  1452426           24: Redemption         9.000         1.0
# 19990  1457688  Love Under Construction         0.000         0.0
# 19991  1463030            Beyond Limits        10.000         3.0
# 19993  1471503      Ashi Hi Jamva Jamvi         2.000         1.0
# 19994  1472280              Winter Dawn         0.000         0.0
#
#       release_date      revenue  runtime      budget original_language  \
# 0       1995-12-09    4257354.0     98.0   4000000.0                en
# ...

# %%
tmdb_df.reset_index(drop=True, inplace=True)

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12020 entries, 0 to 12019
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12020 non-null  int64
#  1   title                    12020 non-null  object
#  2   vote_average             12020 non-null  float64
#  3   vote_count               12020 non-null  float64
#  4   release_date             12020 non-null  object
#  5   revenue                  12020 non-null  float64
#  6   runtime                  12020 non-null  float64
#  7   budget                   12020 non-null  float64
#  8   original_language        12020 non-null  object
#  9   popularity               12020 non-null  float64
#  10  genres                   12020 non-null  object
#  11  production_companies     11618 non-null  object
#  12  production_countries     11769 non-null  object
#  13  cast                     11970 non-null  object
# ...

# %%
print(tmdb_df.isna().sum())
# Out:
# id                            0
# title                         0
# vote_average                  0
# vote_count                    0
# release_date                  0
# revenue                       0
# runtime                       0
# budget                        0
# original_language             0
# popularity                    0
# genres                        0
# production_companies        402
# production_countries        251
# cast                         50
# director                     50
# director_of_photography    1721
# writers                     307
# producers                   912
# music_composer             2933
# imdb_rating                   0
# imdb_votes                    0
# dtype: int64

# %%
tmdb_df['profit_percentage'] = (((tmdb_df['revenue'] - tmdb_df['budget']) / tmdb_df['budget']) * 100)

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12020 entries, 0 to 12019
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12020 non-null  int64
#  1   title                    12020 non-null  object
#  2   vote_average             12020 non-null  float64
#  3   vote_count               12020 non-null  float64
#  4   release_date             12020 non-null  object
#  5   revenue                  12020 non-null  float64
#  6   runtime                  12020 non-null  float64
#  7   budget                   12020 non-null  float64
#  8   original_language        12020 non-null  object
#  9   popularity               12020 non-null  float64
#  10  genres                   12020 non-null  object
#  11  production_companies     11618 non-null  object
#  12  production_countries     11769 non-null  object
#  13  cast                     11970 non-null  object
# ...

# %%
print(tmdb_df.isna().sum())
# Out:
# id                            0
# title                         0
# vote_average                  0
# vote_count                    0
# release_date                  0
# revenue                       0
# runtime                       0
# budget                        0
# original_language             0
# popularity                    0
# genres                        0
# production_companies        402
# production_countries        251
# cast                         50
# director                     50
# director_of_photography    1721
# writers                     307
# producers                   912
# music_composer             2933
# imdb_rating                   0
# imdb_votes                    0
# profit_percentage             0
# dtype: int64

# %%
tmdb_df
# Out:
#             id                    title  vote_average  vote_count  \
# 0            5               Four Rooms         5.861      2687.0
# 1            6           Judgment Night         6.500       349.0
# 2           11                Star Wars         8.204     21103.0
# 3           12             Finding Nemo         7.815     19616.0
# 4           13             Forrest Gump         8.468     28113.0
# ...        ...                      ...           ...         ...
# 12015  1452426           24: Redemption         9.000         1.0
# 12016  1457688  Love Under Construction         0.000         0.0
# 12017  1463030            Beyond Limits        10.000         3.0
# 12018  1471503      Ashi Hi Jamva Jamvi         2.000         1.0
# 12019  1472280              Winter Dawn         0.000         0.0
#
#       release_date      revenue  runtime      budget original_language  \
# 0       1995-12-09    4257354.0     98.0   4000000.0                en
# ...

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12020 entries, 0 to 12019
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12020 non-null  int64
#  1   title                    12020 non-null  object
#  2   vote_average             12020 non-null  float64
#  3   vote_count               12020 non-null  float64
#  4   release_date             12020 non-null  object
#  5   revenue                  12020 non-null  float64
#  6   runtime                  12020 non-null  float64
#  7   budget                   12020 non-null  float64
#  8   original_language        12020 non-null  object
#  9   popularity               12020 non-null  float64
#  10  genres                   12020 non-null  object
#  11  production_companies     11618 non-null  object
#  12  production_countries     11769 non-null  object
#  13  cast                     11970 non-null  object
# ...

# %%
tmdb_df.to_csv('tmdb_profit.csv', index=False)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Marteldelfer/PISI3/blob/analise-exploratoria/tmdb_completo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
tmdb_df = pd.read_csv('TMDB_all_movies.csv')
tmdb_df.head()
# Out:
#    id                             title  vote_average  vote_count    status  \
# 0   2                             Ariel         7.100       346.0  Released
# 1   3               Shadows in Paradise         7.293       409.0  Released
# 2   5                        Four Rooms         5.861      2687.0  Released
# 3   6                    Judgment Night         6.500       349.0  Released
# 4   8  Life in Loops (A Megacities RMX)         7.500        27.0  Released
#
#   release_date     revenue  runtime      budget    imdb_id  ...  \
# 0   1988-10-21         0.0     73.0         0.0  tt0094675  ...
# 1   1986-10-17         0.0     74.0         0.0  tt0092149  ...
# 2   1995-12-09   4257354.0     98.0   4000000.0  tt0113101  ...
# 3   1993-10-15  12136938.0    109.0  21000000.0  tt0107286  ...
# 4   2006-01-01         0.0     80.0     42000.0  tt0825671  ...
#
#                          spoken_languages  \
# 0                                   suomi
# ...

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088906 entries, 0 to 1088905
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   id                       1088906 non-null  int64
#  1   title                    1088893 non-null  object
#  2   vote_average             1088904 non-null  float64
#  3   vote_count               1088904 non-null  float64
#  4   status                   1088904 non-null  object
#  5   release_date             964178 non-null   object
#  6   revenue                  1088904 non-null  float64
#  7   runtime                  1088904 non-null  float64
#  8   budget                   1088904 non-null  float64
#  9   imdb_id                  616234 non-null   object
#  10  original_language        1088904 non-null  object
#  11  original_title           1088894 non-null  object
#  12  overview                 893007 non-null   object
# ...

# %%
tmdb = tmdb_df[tmdb_df['status'] == 'Released']
tmdb = tmdb_df[tmdb_df['budget'] != 0]
tmdb = tmdb_df[tmdb_df['revenue'] != 0]
tmdb.head()
# Out:
#    id           title  vote_average  vote_count    status release_date  \
# 2   5      Four Rooms         5.861      2687.0  Released   1995-12-09
# 3   6  Judgment Night         6.500       349.0  Released   1993-10-15
# 6  11       Star Wars         8.204     21103.0  Released   1977-05-25
# 7  12    Finding Nemo         7.815     19616.0  Released   2003-05-30
# 8  13    Forrest Gump         8.468     28113.0  Released   1994-06-23
#
#        revenue  runtime      budget    imdb_id  ... spoken_languages  \
# 2    4257354.0     98.0   4000000.0  tt0113101  ...          English
# 3   12136938.0    109.0  21000000.0  tt0107286  ...          English
# 6  775398007.0    121.0  11000000.0  tt0076759  ...          English
# 7  940335536.0    100.0  94000000.0  tt0266543  ...          English
# 8  677387716.0    142.0  55000000.0  tt0109830  ...          English
#
#                                                 cast  \
# 2  Quinn Hellerman, Lawrence Bender, Tim Roth, La...
# ...

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25449 entries, 2 to 1088905
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       25449 non-null  int64
#  1   title                    25447 non-null  object
#  2   vote_average             25447 non-null  float64
#  3   vote_count               25447 non-null  float64
#  4   status                   25447 non-null  object
#  5   release_date             23964 non-null  object
#  6   revenue                  25447 non-null  float64
#  7   runtime                  25447 non-null  float64
#  8   budget                   25447 non-null  float64
#  9   imdb_id                  21317 non-null  object
#  10  original_language        25447 non-null  object
#  11  original_title           25447 non-null  object
#  12  overview                 23767 non-null  object
#  13  popularity               25447 non-null  float64
# ...

# %%
tmdb = tmdb.drop(columns=['status', 'imdb_id', 'original_title', 'overview', 'tagline', 'spoken_languages', 'poster_path'])
tmdb.head()
# Out:
#    id           title  vote_average  vote_count release_date      revenue  \
# 2   5      Four Rooms         5.861      2687.0   1995-12-09    4257354.0
# 3   6  Judgment Night         6.500       349.0   1993-10-15   12136938.0
# 6  11       Star Wars         8.204     21103.0   1977-05-25  775398007.0
# 7  12    Finding Nemo         7.815     19616.0   2003-05-30  940335536.0
# 8  13    Forrest Gump         8.468     28113.0   1994-06-23  677387716.0
#
#    runtime      budget original_language  popularity  ...  \
# 2     98.0   4000000.0                en      9.6284  ...
# 3    109.0  21000000.0                en      4.5607  ...
# 6    121.0  11000000.0                en     67.2931  ...
# 7    100.0  94000000.0                en     18.2106  ...
# 8    142.0  55000000.0                en     27.4853  ...
#
#                                 production_companies  \
# 2                              Miramax, A Band Apart
# 3       Largo Entertainment, JVC, Universal Pictures
# ...

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25449 entries, 2 to 1088905
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       25449 non-null  int64
#  1   title                    25447 non-null  object
#  2   vote_average             25447 non-null  float64
#  3   vote_count               25447 non-null  float64
#  4   release_date             23964 non-null  object
#  5   revenue                  25447 non-null  float64
#  6   runtime                  25447 non-null  float64
#  7   budget                   25447 non-null  float64
#  8   original_language        25447 non-null  object
#  9   popularity               25447 non-null  float64
#  10  genres                   23882 non-null  object
#  11  production_companies     21714 non-null  object
#  12  production_countries     22168 non-null  object
#  13  cast                     24202 non-null  object
# ...

# %%
print(tmdb.isna().sum())
# Out:
# id                             0
# title                          2
# vote_average                   2
# vote_count                     2
# release_date                1485
# revenue                        2
# runtime                        2
# budget                         2
# original_language              2
# popularity                     2
# genres                      1567
# production_companies        3735
# production_countries        3281
# cast                        1247
# director                    1636
# director_of_photography     8143
# writers                     3683
# producers                   6280
# music_composer             11827
# imdb_rating                 5248
# imdb_votes                  5248
# dtype: int64

# %%
tmdb_clean_df = tmdb.dropna(subset=['title', 'genres', 'imdb_rating', 'imdb_votes', 'release_date'])
tmdb_clean_df.tail()
# Out:
#               id                     title  vote_average  vote_count  \
# 1076066  1457688   Love Under Construction           0.0         0.0
# 1080475  1463030             Beyond Limits          10.0         3.0
# 1086724  1470494  The Adventures of Sinbad           0.0         0.0
# 1087501  1471503       Ashi Hi Jamva Jamvi           2.0         1.0
# 1088156  1472280               Winter Dawn           0.0         0.0
#
#         release_date    revenue  runtime    budget original_language  \
# 1076066   2025-02-28      600.0    186.0     600.0                ml
# 1080475   2025-03-07   145000.0     93.0   62000.0                en
# 1086724   2013-03-22  6060000.0    110.0       0.0                hi
# 1087501   2025-04-10   141739.0    129.0  234280.0                mr
# 1088156   2007-04-22    12500.0     15.0    2400.0                pt
#
#          popularity  ...     production_companies production_countries  \
# ...

# %%
print(tmdb_clean_df.isna().sum())
# Out:
# id                            0
# title                         0
# vote_average                  0
# vote_count                    0
# release_date                  0
# revenue                       0
# runtime                       0
# budget                        0
# original_language             0
# popularity                    0
# genres                        0
# production_companies        944
# production_countries        470
# cast                        149
# director                     95
# director_of_photography    3857
# writers                     883
# producers                  2309
# music_composer             6466
# imdb_rating                   0
# imdb_votes                    0
# dtype: int64

# %%
tmdb_clean_df.reset_index(drop=True, inplace=True)
tmdb_clean_df.tail()
# Out:
#             id                     title  vote_average  vote_count  \
# 19990  1457688   Love Under Construction           0.0         0.0
# 19991  1463030             Beyond Limits          10.0         3.0
# 19992  1470494  The Adventures of Sinbad           0.0         0.0
# 19993  1471503       Ashi Hi Jamva Jamvi           2.0         1.0
# 19994  1472280               Winter Dawn           0.0         0.0
#
#       release_date    revenue  runtime    budget original_language  \
# 19990   2025-02-28      600.0    186.0     600.0                ml
# 19991   2025-03-07   145000.0     93.0   62000.0                en
# 19992   2013-03-22  6060000.0    110.0       0.0                hi
# 19993   2025-04-10   141739.0    129.0  234280.0                mr
# 19994   2007-04-22    12500.0     15.0    2400.0                pt
#
#        popularity  ...     production_companies production_countries  \
# 19990      0.3335  ...  Rejaputhra Visual Media                India
# ...

# %%
tmdb_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19995 entries, 0 to 19994
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       19995 non-null  int64
#  1   title                    19995 non-null  object
#  2   vote_average             19995 non-null  float64
#  3   vote_count               19995 non-null  float64
#  4   release_date             19995 non-null  object
#  5   revenue                  19995 non-null  float64
#  6   runtime                  19995 non-null  float64
#  7   budget                   19995 non-null  float64
#  8   original_language        19995 non-null  object
#  9   popularity               19995 non-null  float64
#  10  genres                   19995 non-null  object
#  11  production_companies     19051 non-null  object
#  12  production_countries     19525 non-null  object
#  13  cast                     19846 non-null  object
# ...

# %%
tmdb_clean_df.to_csv('tmdb_completo.csv', index=False)
